# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import geopandas as gpd

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0            naze  28.3667  129.4833     20.51        89          98
# 1        1             eyl   7.9803   49.8164     22.92        76          82
# 2        2          avarua -21.2078 -159.7750     27.03        89          75
# 3        3      sao filipe  14.8961  -24.4956     22.14        66          92
# 4        4  port macquarie -31.4333  152.9167     26.61        58           0
#
#    Wind Speed Country        Date
# 0        5.47      JP  1670210251
# 1        7.02      SO  1670210439
# 2        1.54      CK  1670210439
# 3        1.22      CV  1670210440
# 4        6.06      AU  1670210440

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_data_df.rename(columns = {'Lat': 'Latitude', 'Lng': 'Longitude'}, inplace = True)
city_data_gdf = gpd.GeoDataFrame(
    city_data_df, geometry = gpd.points_from_xy(city_data_df.Longitude, city_data_df.Latitude))
# Display the map
city_data_gdf.hvplot(geo = True, tiles = True, size = 'Humidity', frame_width = 875)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
type(city_data_gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# Narrow down cities that fit criteria and drop any results with null values
picky_df = city_data_df.loc[
    (city_data_df['Max Temp'] < 35) &
    (city_data_df['Max Temp'] > 19) &
    (city_data_df['Wind Speed'] < 5) &
    (city_data_df['Cloudiness'] < 10),:]

# Drop any rows with null values
picky_df = picky_df.dropna()

# Display sample data
picky_df
# Out:
#      City_ID                 City  Latitude  Longitude  Max Temp  Humidity  \
# 7          7            cape town  -33.9258    18.4232     19.10        66
# 19        19            innisfail  -17.5333   146.0333     28.92        55
# 22        22        marsh harbour   26.5412   -77.0636     22.90        65
# 39        39               gashua   12.8710    11.0482     21.07        17
# 46        46             kochinda   21.7333    84.3500     20.74        49
# 57        57                kapaa   22.0752  -159.3190     27.18        79
# 102      102                pisco  -13.7000   -76.2167     19.03        82
# 132      132                 tura   25.5198    90.2201     21.47        63
# 141      141              ballina  -28.8667   153.5667     28.34        61
# 178      178              hualmay  -11.0964   -77.6139     19.20        83
# 179      179                 ocos   14.5094   -92.1933     25.10        78
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = picky_df[['City','Country','Latitude','Longitude','Humidity','geometry']]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
# C:\Users\Danielle Anderson\AppData\Local\Temp\ipykernel_16828\2338030543.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = ''
#                     City Country  Latitude  Longitude  Humidity  \
# 7              cape town      ZA  -33.9258    18.4232        66
# 19             innisfail      AU  -17.5333   146.0333        55
# 22         marsh harbour      BS   26.5412   -77.0636        65
# 39                gashua      NG   12.8710    11.0482        17
# 46              kochinda      IN   21.7333    84.3500        49
# 57                 kapaa      US   22.0752  -159.3190        79
# 102                pisco      PE  -13.7000   -76.2167        82
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    'categories':'accommodation',
    'limit':5,
    'filter':'',
    'bias':'',
    'apiKey':geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df['Latitude']
    longitude = hotel_df['Longitude']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# cape town - nearest hotel: No hotel found
# innisfail - nearest hotel: No hotel found
# marsh harbour - nearest hotel: No hotel found
# gashua - nearest hotel: No hotel found
# kochinda - nearest hotel: No hotel found
# kapaa - nearest hotel: No hotel found
# pisco - nearest hotel: No hotel found
# tura - nearest hotel: No hotel found
# ballina - nearest hotel: No hotel found
# hualmay - nearest hotel: No hotel found
# ocos - nearest hotel: No hotel found
# tocopilla - nearest hotel: No hotel found
# salto - nearest hotel: No hotel found
# adrar - nearest hotel: No hotel found
# namwala - nearest hotel: No hotel found
# kaduna - nearest hotel: No hotel found
# saint-pierre - nearest hotel: No hotel found
# puerto escondido - nearest hotel: No hotel found
# aguada de pasajeros - nearest hotel: No hotel found
# nueve de julio - nearest hotel: No hotel found
# yenagoa - nearest hotel: No hotel found
# gweta - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_gdf = gpd.GeoDataFrame(hotel_df)

# Display the map
hotel_gdf.hvplot(geo = True, tiles = True, size = 'Humidity', frame_width = 875, hover_cols = [
    'Latitude','Longitude','City','Humidity','Hotel Name','Country'])
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (Humidity,City,Hotel Name,Country)
